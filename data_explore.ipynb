# %%
import pandas as pd

# %%
df = pd.read_csv('quis_data.csv')

# %%
# show column names
df.columns
# Out:
# Index(['id', 'name', 'city', 'country_code', 'position', 'about', 'posts',
#        'groups', 'current_company', 'experience', 'url', 'people_also_viewed',
#        'educations_details', 'education', 'recommendations_count', 'avatar',
#        'courses', 'languages', 'certifications', 'recommendations',
#        'volunteer_experience', 'followers', 'connections',
#        'current_company_company_id', 'current_company_name', 'publications',
#        'patents', 'projects', 'organizations', 'location', 'input_url',
#        'linkedin_id', 'activity', 'linkedin_num_id', 'banner_image',
#        'honors_and_awards', 'similar_profiles', 'default_avatar',
#        'memorialized_account', 'bio_links'],
#       dtype='object')

# %%
before = len(df)
df = df.drop_duplicates(subset=["linkedin_id"])
after = len(df)

print(f"Drop duplicates: {before} → {after} (removed {before - after} rows)")
# Out:
# Drop duplicates: 95610 → 95609 (removed 1 rows)

# %%
df.head(1000)
# Out:
#                                 id                   name  \
# 0         mohamed-ishmael-b757b442        Mohamed Ishmael
# 1         michael-gradess-22195219        Michael Gradess
# 2           robert-clarke-63283056          Robert Clarke
# 3         suzanne-zwemer-1169a6101         Suzanne Zwemer
# 4                       mike-oneil            Mike O'Neil
# ..                             ...                    ...
# 995  ann-sheridan-realtor-7b522712  Ann Sheridan, Realtor
# 996                      jack-saad              Jack Saad
# 997                xuyangsophieliu             Xuyang Liu
# 998           mike-rahman-765b8b54            Mike Rahman
# 999          jonathan-kim-8a89a620           Jonathan Kim
#
#                                           city country_code  \
# 0            Brooklyn, New York, United States           US
# 1       Cherry Hill, New Jersey, United States           US
# 2    Philadelphia, Pennsylvania, United States           US
# ...

# %%
df[df['id'].str.contains("You can", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [id, name, city, country_code, position, about, posts, groups, current_company, experience, url, people_also_viewed, educations_details, education, recommendations_count, avatar, courses, languages, certifications, recommendations, volunteer_experience, followers, connections, current_company_company_id, current_company_name, publications, patents, projects, organizations, location, input_url, linkedin_id, activity, linkedin_num_id, banner_image, honors_and_awards, similar_profiles, default_avatar, memorialized_account, bio_links]
# Index: []
#
# [0 rows x 40 columns]
